# %%
import tensorflow as tf
import tensorflow
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPool2D, Flatten, BatchNormalization
from tensorflow.keras.optimizers import SGD
#from tensorflow.keras.utils import np_utils
from tensorflow.keras import utils

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

# %%
import cv2
import numpy as np
import glob
import matplotlib.pyplot as plt
import pandas as pd
import PIL

# %%
files = glob.glob('train/*/*.jpg')

# %%
files
# Out:
# ['train\\ABBOTTS BABBLER\\001.jpg',
#  'train\\ABBOTTS BABBLER\\002.jpg',
#  'train\\ABBOTTS BABBLER\\003.jpg',
#  'train\\ABBOTTS BABBLER\\004.jpg',
#  'train\\ABBOTTS BABBLER\\005.jpg',
#  'train\\ABBOTTS BABBLER\\006.jpg',
#  'train\\ABBOTTS BABBLER\\007.jpg',
#  'train\\ABBOTTS BABBLER\\008.jpg',
#  'train\\ABBOTTS BABBLER\\009.jpg',
#  'train\\ABBOTTS BABBLER\\010.jpg',
#  'train\\ABBOTTS BABBLER\\011.jpg',
#  'train\\ABBOTTS BABBLER\\012.jpg',
#  'train\\ABBOTTS BABBLER\\013.jpg',
#  'train\\ABBOTTS BABBLER\\014.jpg',
#  'train\\ABBOTTS BABBLER\\015.jpg',
#  'train\\ABBOTTS BABBLER\\016.jpg',
#  'train\\ABBOTTS BABBLER\\017.jpg',
#  'train\\ABBOTTS BABBLER\\018.jpg',
#  'train\\ABBOTTS BABBLER\\019.jpg',
#  'train\\ABBOTTS BABBLER\\020.jpg',
#  'train\\ABBOTTS BABBLER\\021.jpg',
#  'train\\ABBOTTS BABBLER\\022.jpg',
#  'train\\ABBOTTS BABBLER\\023.jpg',
#  'train\\ABBOTTS BABBLER\\024.jpg',
#  'train\\ABBOTTS BABBLER\\025.jpg',
#  'train\\ABBOTTS BABBLER\\026.jpg',
# ...

# %%
df = pd.DataFrame(files, columns = ["image"])

# %%
df.head()
# Out:
#                            image
# 0  train\ABBOTTS BABBLER\001.jpg
# 1  train\ABBOTTS BABBLER\002.jpg
# 2  train\ABBOTTS BABBLER\003.jpg
# 3  train\ABBOTTS BABBLER\004.jpg
# 4  train\ABBOTTS BABBLER\005.jpg

# %%
names = []
for i in files:
    data = i.split('\\')[1]
    names.append(data)

# %%
df['class'] = names

# %%
df.head()
# Out:
#                            image            class
# 0  train\ABBOTTS BABBLER\001.jpg  ABBOTTS BABBLER
# 1  train\ABBOTTS BABBLER\002.jpg  ABBOTTS BABBLER
# 2  train\ABBOTTS BABBLER\003.jpg  ABBOTTS BABBLER
# 3  train\ABBOTTS BABBLER\004.jpg  ABBOTTS BABBLER
# 4  train\ABBOTTS BABBLER\005.jpg  ABBOTTS BABBLER

# %%
df2 = pd.read_csv('class_dict.csv')

# %%
df2.head()
# Out:
#    class_index                       class  height  width  scale by  Offset
# 0            0             ABBOTTS BABBLER     150    150         1       0
# 1            1               ABBOTTS BOOBY     150    150         1       0
# 2            2  ABYSSINIAN GROUND HORNBILL     150    150         1       0
# 3            3       AFRICAN CROWNED CRANE     150    150         1       0
# 4            4      AFRICAN EMERALD CUCKOO     150    150         1       0

# %%
df3 = pd.merge(df, df2, how = 'left', on = 'class')

# %%
df4 = df3[['image', 'class_index']]
df4
# Out:
#                                        image  class_index
# 0              train\ABBOTTS BABBLER\001.jpg            0
# 1              train\ABBOTTS BABBLER\002.jpg            0
# 2              train\ABBOTTS BABBLER\003.jpg            0
# 3              train\ABBOTTS BABBLER\004.jpg            0
# 4              train\ABBOTTS BABBLER\005.jpg            0
# ...                                      ...          ...
# 50939  train\YELLOW HEADED BLACKBIRD\155.jpg          349
# 50940  train\YELLOW HEADED BLACKBIRD\156.jpg          349
# 50941  train\YELLOW HEADED BLACKBIRD\157.jpg          349
# 50942  train\YELLOW HEADED BLACKBIRD\158.jpg          349
# 50943  train\YELLOW HEADED BLACKBIRD\159.jpg          349
#
# [50944 rows x 2 columns]

# %%
for i in files:
    data = cv2.imread(i)
    print(data.shape)
# Out:
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# (224, 224, 3)
# ...

# %%
img_test = cv2.imread('./train/YELLOW HEADED BLACKBIRD/005.jpg')

# %%
img_test = cv2.cvtColor(img_test, cv2.COLOR_BGR2RGB)

# %%
img_test_R = img_test[:,:,0]  #R
img_test_G = img_test[:,:,1]  #G
img_test_B = img_test[:,:,2]  #B

# %%
img_test_B
# Out:
# array([[231, 231, 231, ..., 234, 234, 232],
#        [232, 232, 231, ..., 233, 234, 233],
#        [233, 232, 231, ..., 233, 232, 232],
#        ...,
#        [ 71,  48,  52, ..., 232, 232, 232],
#        [146, 136,  81, ..., 233, 232, 230],
#        [177, 196, 179, ..., 230, 231, 232]], dtype=uint8)

# %%
plt.imshow(img_test_R, cmap=plt.cm.gray)

# %%
plt.imshow(img_test_G, cmap=plt.cm.gray)

# %%
plt.imshow(img_test_B, cmap=plt.cm.gray)

# %%
plt.imshow(img_test)
